# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_excel('복합기 크롤링 중복제거.xlsx')
#data = data.rename(columns = {"스펙 목록":"제품 구분","Unnamed:3":"인쇄/출력 방식","Unnamed:4":""})
data1 = data
data1.head()
# Out:
#                상품명       가격        스펙 목록 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   ApeosPort 2560  2125000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 1   ApeosPort 3060  2200000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 2   ApeosPort 3560  2528000  흑백 디지털 복합기        잉크젯      컬러 출력         복사
# 3  ApeosPort C2060  2600000  컬러 디지털 복합기         인쇄         복사         스캔
# 4  ApeosPort C2560  2778170  컬러 디지털 복합기         인쇄         복사         스캔
#
#        Unnamed: 6          Unnamed: 7              Unnamed: 8  \
# 0             복사                  스캔                      팩스
# 1             복사                  스캔                      팩스
# 2             스캔    인쇄 해상도: 4,800dpi                  무한 패키지
# 3   컬러 속도: 23ppm        흑백 속도: 28ppm    인쇄 해상도: 600 x 600dpi
# 4             팩스        컬러 속도: 23ppm            흑백 속도: 25ppm
#
#                  Unnamed: 9  ...  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0         인쇄 해상도: 4,800dpi   ...          NaN          NaN          NaN
# 1         인쇄 해상도: 4,800dpi   ...          NaN          NaN          NaN
# 2                연결방식: USB   ...          NaN          NaN          NaN
# 3                   자동양면인쇄   ...   가로: 699mm    세로: 742mm    높이: 759mm
# 4   인쇄 해상도: 1200 x 1200dpi   ...    무게: 125kg          NaN          NaN
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3   무게: 121kg         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 30 columns]

# %%
data = data[['상품명','가격','스펙 목록']] 
print(data.shape)
data.drop_duplicates(["상품명"],keep="first")
print(data.shape)
# Out:
# (5901, 3)
# (5901, 3)

# %%
data['상태'] = np.where(data['가격']==0,'단종','시가')
data
# Out:
# <ipython-input-121-b5686f2159ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['상태'] = np.where(data['가격']==0,'단종','시가')
#                           상품명       가격        스펙 목록  상태
# 0              ApeosPort 2560  2125000  흑백 디지털 복합기   시가
# 1              ApeosPort 3060  2200000  흑백 디지털 복합기   시가
# 2              ApeosPort 3560  2528000  흑백 디지털 복합기   시가
# 3             ApeosPort C2060  2600000  컬러 디지털 복합기   시가
# 4             ApeosPort C2560  2778170  컬러 디지털 복합기   시가
# ...                       ...      ...          ...  ..
# 5896       코니카미놀타 bizhub C451        0  컬러 디지털 복합기   단종
# 5897            코니카미놀타 C022DN        0  컬러 디지털 복합기   단종
# 5898            코니카미놀타 C028DN        0  흑백 디지털 복합기   단종
# 5899            코니카미놀타 C036DN        0  흑백 디지털 복합기   단종
# 5900  코니카미놀타 MagiColor 4690MF        0         복합기   단종
#
# [5901 rows x 4 columns]

# %%
aa= "프린터"
if (aa=="프린터") | (aa=="사무기기"):
    print("asdaas")
# Out:
# asdaas

# %%
arr_column = data1['기능1'].values
print(arr_column)
i= 0 
print(arr_column[1])
for i in range(0,5901):
    column = arr_column[i]
    
    data['기능'] = np.where( (column=="인쇄") | (column=="복사") | (column=="스캔") | (column=="팩스") | (column=="잉크젯") | (column=="컬러 출력") | (column=="레이저") | (column=="레이저젯") | (column=="흑백(모노) 출력") ,'asdasd','not')
data
# Out:
# [' 잉크젯 ' ' 잉크젯 ' ' 잉크젯 ' ... ' 레이저젯 ' ' 레이저 ' ' 잉크젯 ']
#  잉크젯
# <ipython-input-118-897c79b78f55>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['기능'] = np.where( (column=="인쇄") | (column=="복사") | (column=="스캔") | (column=="팩스") | (column=="잉크젯") | (column=="컬러 출력") | (column=="레이저") | (column=="레이저젯") | (column=="흑백(모노) 출력") ,'asdasd','not')
#                           상품명       가격        스펙 목록  상태   기능
# 0              ApeosPort 2560  2125000  흑백 디지털 복합기   시가  not
# 1              ApeosPort 3060  2200000  흑백 디지털 복합기   시가  not
# 2              ApeosPort 3560  2528000  흑백 디지털 복합기   시가  not
# 3             ApeosPort C2060  2600000  컬러 디지털 복합기   시가  not
# 4             ApeosPort C2560  2778170  컬러 디지털 복합기   시가  not
# ...                       ...      ...          ...  ..  ...
# 5896       코니카미놀타 bizhub C451        0  컬러 디지털 복합기   단종  not
# 5897            코니카미놀타 C022DN        0  컬러 디지털 복합기   단종  not
# 5898            코니카미놀타 C028DN        0  흑백 디지털 복합기   단종  not
# 5899            코니카미놀타 C036DN        0  흑백 디지털 복합기   단종  not
# 5900  코니카미놀타 MagiColor 4690MF        0         복합기   단종  not
#
# [5901 rows x 5 columns]

# %%
a = np.array(['apple', 'orange', 'apple', 'banana'])

arr_index = np.where(a == 'apple')

print (arr_index)
      
print (a[arr_index])
# Out:
# (array([0, 2], dtype=int64),)
# ['apple' 'apple']

# %%
item_user_table = pd.DataFrame(data=np.random.randint(0,2,size=(5901,5)), index=data['상품명'], columns=['대표님','팀장님','지은','시은','준영'])
item_user_table
# Out:
#                          대표님  팀장님  지은  시은  준영
# 상품명
# ApeosPort 2560             0    1   0   1   1
# ApeosPort 3060             0    1   1   0   1
# ApeosPort 3560             0    0   1   0   1
# ApeosPort C2060            1    0   0   0   0
# ApeosPort C2560            1    1   0   1   1
# ...                      ...  ...  ..  ..  ..
# 코니카미놀타 bizhub C451         0    0   1   1   0
# 코니카미놀타 C022DN              0    0   1   1   1
# 코니카미놀타 C028DN              0    0   0   0   1
# 코니카미놀타 C036DN              0    1   0   0   0
# 코니카미놀타 MagiColor 4690MF    1    1   0   1   1
#
# [5901 rows x 5 columns]

# %%
printer_sim = cosine_similarity(item_user_table,item_user_table)
printer_sim_df = pd.DataFrame(data=printer_sim,index=item_user_table.index,columns=item_user_table.index)
printer_sim_df
# Out:
# 상품명                      ApeosPort 2560  ApeosPort 3060  ApeosPort 3560  \
# 상품명
# ApeosPort 2560                 1.000000        0.666667        0.408248
# ApeosPort 3060                 0.666667        1.000000        0.816497
# ApeosPort 3560                 0.408248        0.816497        1.000000
# ApeosPort C2060                0.000000        0.000000        0.000000
# ApeosPort C2560                0.866025        0.577350        0.353553
# ...                                 ...             ...             ...
# 코니카미놀타 bizhub C451             0.408248        0.408248        0.500000
# 코니카미놀타 C022DN                  0.666667        0.666667        0.816497
# 코니카미놀타 C028DN                  0.577350        0.577350        0.707107
# 코니카미놀타 C036DN                  0.577350        0.577350        0.000000
# 코니카미놀타 MagiColor 4690MF        0.866025        0.577350        0.353553
#
# 상품명                      ApeosPort C2060  ApeosPort C2560  ApeosPort C3060  \
# 상품명
# ApeosPort 2560                       0.0         0.866025         0.000000
# ApeosPort 3060                       0.0         0.577350         0.408248
# ApeosPort 3560                       0.0         0.353553         0.500000
# ApeosPort C2060                      1.0         0.500000         0.707107
# ApeosPort C2560                      0.5         1.000000         0.353553
# ...                                  ...              ...              ...
# 코니카미놀타 bizhub C451                   0.0         0.353553         0.500000
# 코니카미놀타 C022DN                        0.0         0.577350         0.408248
# 코니카미놀타 C028DN                        0.0         0.500000         0.000000
# 코니카미놀타 C036DN                        0.0         0.500000         0.000000
# 코니카미놀타 MagiColor 4690MF              0.5         1.000000         0.353553
#
# 상품명                      Apeosport-II 5010  Apeosport-II 6000  \
# 상품명
# ApeosPort 2560                    0.866025           0.408248
# ApeosPort 3060                    0.866025           0.408248
# ApeosPort 3560                    0.707107           0.500000
# ApeosPort C2060                   0.000000           0.000000
# ApeosPort C2560                   0.750000           0.353553
# ...                                    ...                ...
# 코니카미놀타 bizhub C451                0.707107           1.000000
# 코니카미놀타 C022DN                     0.866025           0.816497
# 코니카미놀타 C028DN                     0.500000           0.000000
# 코니카미놀타 C036DN                     0.500000           0.000000
# 코니카미놀타 MagiColor 4690MF           0.750000           0.353553
#
# 상품명                      Apeosport-II 7000  Apeosport-II C2200 CP  ...  \
# 상품명                                                                ...
# ApeosPort 2560                    0.666667               1.000000  ...
# ApeosPort 3060                    1.000000               0.666667  ...
# ApeosPort 3560                    0.816497               0.408248  ...
# ApeosPort C2060                   0.000000               0.000000  ...
# ApeosPort C2560                   0.577350               0.866025  ...
# ...                                    ...                    ...  ...
# 코니카미놀타 bizhub C451                0.408248               0.408248  ...
# 코니카미놀타 C022DN                     0.666667               0.666667  ...
# 코니카미놀타 C028DN                     0.577350               0.577350  ...
# 코니카미놀타 C036DN                     0.577350               0.577350  ...
# 코니카미놀타 MagiColor 4690MF           0.577350               0.866025  ...
#
# 상품명                      코니카미놀타 Bizhub C025DNi  코니카미놀타 bizhub C200  \
# 상품명
# ApeosPort 2560                        0.577350            0.408248
# ApeosPort 3060                        0.577350            0.408248
# ApeosPort 3560                        0.707107            0.500000
# ApeosPort C2060                       0.000000            0.000000
# ApeosPort C2560                       0.500000            0.353553
# ...                                        ...                 ...
# 코니카미놀타 bizhub C451                    0.000000            1.000000
# 코니카미놀타 C022DN                         0.577350            0.816497
# 코니카미놀타 C028DN                         1.000000            0.000000
# 코니카미놀타 C036DN                         0.000000            0.000000
# 코니카미놀타 MagiColor 4690MF               0.500000            0.353553
#
# 상품명                      코니카미놀타 bizhub C220  코니카미놀타 Bizhub C225DN  \
# 상품명
# ApeosPort 2560                     0.577350              0.816497
# ApeosPort 3060                     0.000000              0.408248
# ApeosPort 3560                     0.000000              0.000000
# ApeosPort C2060                    0.000000              0.000000
# ApeosPort C2560                    0.500000              0.707107
# ...                                     ...                   ...
# 코니카미놀타 bizhub C451                 0.707107              0.500000
# 코니카미놀타 C022DN                      0.577350              0.408248
# 코니카미놀타 C028DN                      0.000000              0.000000
# 코니카미놀타 C036DN                      0.000000              0.707107
# 코니카미놀타 MagiColor 4690MF            0.500000              0.707107
#
# 상품명                      코니카미놀타 bizhub C360  코니카미놀타 bizhub C451  \
# 상품명
# ApeosPort 2560                     0.666667            0.408248
# ApeosPort 3060                     1.000000            0.408248
# ApeosPort 3560                     0.816497            0.500000
# ApeosPort C2060                    0.000000            0.000000
# ApeosPort C2560                    0.577350            0.353553
# ...                                     ...                 ...
# 코니카미놀타 bizhub C451                 0.408248            1.000000
# 코니카미놀타 C022DN                      0.666667            0.816497
# 코니카미놀타 C028DN                      0.577350            0.000000
# 코니카미놀타 C036DN                      0.577350            0.000000
# 코니카미놀타 MagiColor 4690MF            0.577350            0.353553
#
# 상품명                      코니카미놀타 C022DN  코니카미놀타 C028DN  코니카미놀타 C036DN  \
# 상품명
# ApeosPort 2560                0.666667       0.577350        0.57735
# ApeosPort 3060                0.666667       0.577350        0.57735
# ApeosPort 3560                0.816497       0.707107        0.00000
# ApeosPort C2060               0.000000       0.000000        0.00000
# ApeosPort C2560               0.577350       0.500000        0.50000
# ...                                ...            ...            ...
# 코니카미놀타 bizhub C451            0.816497       0.000000        0.00000
# 코니카미놀타 C022DN                 1.000000       0.577350        0.00000
# 코니카미놀타 C028DN                 0.577350       1.000000        0.00000
# 코니카미놀타 C036DN                 0.000000       0.000000        1.00000
# 코니카미놀타 MagiColor 4690MF       0.577350       0.500000        0.50000
#
# 상품명                      코니카미놀타 MagiColor 4690MF
# 상품명
# ApeosPort 2560                          0.866025
# ApeosPort 3060                          0.577350
# ApeosPort 3560                          0.353553
# ApeosPort C2060                         0.500000
# ApeosPort C2560                         1.000000
# ...                                          ...
# 코니카미놀타 bizhub C451                      0.353553
# 코니카미놀타 C022DN                           0.577350
# 코니카미놀타 C028DN                           0.500000
# 코니카미놀타 C036DN                           0.500000
# 코니카미놀타 MagiColor 4690MF                 1.000000
#
# [5901 rows x 5901 columns]

# %%
printer_sim_df['ApeosPort C2560']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b5bf186d2e7> in <module>
# ----> 1 printer_sim_df['ApeosPort C2560']
#
# NameError: name 'printer_sim_df' is not defined
