# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_excel('./복합기 크롤링 중복제거.xlsx')
#data = data.rename(columns = {"스펙 목록":"제품 구분","Unnamed:3":"인쇄/출력 방식","Unnamed:4":""})
data1 = data
data1.head()
# Out:
#                상품명       가격        스펙 목록 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   ApeosPort 2560  2125000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 1   ApeosPort 3060  2200000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 2   ApeosPort 3560  2528000  흑백 디지털 복합기        잉크젯      컬러 출력         복사
# 3  ApeosPort C2060  2600000  컬러 디지털 복합기         인쇄         복사         스캔
# 4  ApeosPort C2560  2778170  컬러 디지털 복합기         인쇄         복사         스캔
#
#        Unnamed: 6          Unnamed: 7              Unnamed: 8  \
# 0             복사                  스캔                      팩스
# 1             복사                  스캔                      팩스
# 2             스캔    인쇄 해상도: 4,800dpi                  무한 패키지
# 3   컬러 속도: 23ppm        흑백 속도: 28ppm    인쇄 해상도: 600 x 600dpi
# 4             팩스        컬러 속도: 23ppm            흑백 속도: 25ppm
#
#                  Unnamed: 9  ...  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0         인쇄 해상도: 4,800dpi   ...          NaN          NaN          NaN
# ...

# %%
data = data[['상품명','가격','스펙 목록']] 
print(data.shape)
data.drop_duplicates(["상품명"],keep="first")
print(data.shape)
# Out:
# (5901, 3)
# (5901, 3)

# %%
data['상태'] = np.where(data['가격']==0,'단종','시가')
data
# Out:
# <ipython-input-4-b5686f2159ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['상태'] = np.where(data['가격']==0,'단종','시가')
#                           상품명       가격        스펙 목록  상태
# 0              ApeosPort 2560  2125000  흑백 디지털 복합기   시가
# 1              ApeosPort 3060  2200000  흑백 디지털 복합기   시가
# 2              ApeosPort 3560  2528000  흑백 디지털 복합기   시가
# 3             ApeosPort C2060  2600000  컬러 디지털 복합기   시가
# 4             ApeosPort C2560  2778170  컬러 디지털 복합기   시가
# ...                       ...      ...          ...  ..
# 5896       코니카미놀타 bizhub C451        0  컬러 디지털 복합기   단종
# 5897            코니카미놀타 C022DN        0  컬러 디지털 복합기   단종
# 5898            코니카미놀타 C028DN        0  흑백 디지털 복합기   단종
# ...

# %%
arr_column = data1['기능1'].values
print(arr_column)
i= 0 
print(arr_column[4])
for i in range(1,5902):
    column = arr_column[i]l,k
    data['기능'] = np.where( (column=="인쇄") | (column=="복사") | (column=="스캔") | (column=="팩스") | (column=="잉크젯") | (column=="컬러 출력") | (column=="레이저") | (column=="레이저젯") | (column=="흑백(모노) 출력") ,'asdasd','not')
data
# Out:
#   File "<ipython-input-6-53302f394605>", line 6
#     column = arr_column[i]l,k
#                           ^
# SyntaxError: invalid syntax

# %%
item_user_table = pd.DataFrame(data=np.random.randint(1,6,size=(5901,15)), index=data['상품명'], columns=['대표님','팀장님','지은','시은','준영','도현','실장님','비둘기','세무사님','이룬아이티','아리오','후반기인턴1','후반기인턴2','후반기인턴3','정직원1'])
item_user_table
# Out:
#                          대표님  팀장님  지은  시은  준영  도현  실장님  비둘기  세무사님  이룬아이티  아리오  \
# 상품명
# ApeosPort 2560             4    3   4   2   1   4    4    5     3      4    2
# ApeosPort 3060             2    4   1   2   1   1    2    5     1      1    3
# ApeosPort 3560             1    5   4   1   1   2    3    3     1      1    3
# ApeosPort C2060            2    1   2   2   1   5    4    5     1      2    5
# ApeosPort C2560            2    3   1   4   5   4    5    5     3      4    1
# ...                      ...  ...  ..  ..  ..  ..  ...  ...   ...    ...  ...
# 코니카미놀타 bizhub C451         5    2   4   1   5   3    4    4     4      2    2
# 코니카미놀타 C022DN              2    5   5   4   5   2    3    4     3      1    4
# 코니카미놀타 C028DN              1    1   2   4   1   3    4    2     5      1    5
# 코니카미놀타 C036DN              3    1   1   3   1   1    5    5     1      3    1
# 코니카미놀타 MagiColor 4690MF    1    1   1   5   3   3    1    1     3      2    4
#
# ...

# %%
printer_sim = cosine_similarity(item_user_table,item_user_table)
printer_sim_df = pd.DataFrame(data=printer_sim,index=item_user_table.index,columns=item_user_table.index)
printer_sim_df
# Out:
# 상품명                      ApeosPort 2560  ApeosPort 3060  ApeosPort 3560  \
# 상품명
# ApeosPort 2560                 1.000000        0.755929        0.819513
# ApeosPort 3060                 0.755929        1.000000        0.867291
# ApeosPort 3560                 0.819513        0.867291        1.000000
# ApeosPort C2060                0.820948        0.863845        0.826709
# ApeosPort C2560                0.822226        0.861098        0.770086
# ...                                 ...             ...             ...
# 코니카미놀타 bizhub C451             0.840343        0.822613        0.794981
# 코니카미놀타 C022DN                  0.820990        0.840602        0.853854
# 코니카미놀타 C028DN                  0.727291        0.785022        0.754527
# 코니카미놀타 C036DN                  0.757937        0.883292        0.701985
# 코니카미놀타 MagiColor 4690MF        0.692260        0.664188        0.658336
#
# 상품명                      ApeosPort C2060  ApeosPort C2560  ApeosPort C3060  \
# 상품명
# ...

# %%
printer_sim_df['ApeosPort 2560'].head()
# Out:
# 상품명
# ApeosPort 2560     1.000000
# ApeosPort 3060     0.755929
# ApeosPort 3560     0.819513
# ApeosPort C2060    0.820948
# ApeosPort C2560    0.822226
# Name: ApeosPort 2560, dtype: float64

# %%
printer_sim_df["ApeosPort 2560"].sort_values(ascending=False)[:10]
# Out:
# 상품명
# ApeosPort 2560                    1.000000
# HP 오피스젯 프로 8720 무한공급기             0.986136
# Apeosport-II C2200 CP             0.971040
# Epson Stylus TX110 무한공급기          0.968365
# Epson Stylus Photo RX610          0.968288
# Canon IR C3125                    0.967145
# 삼성전자 잉크젯 플러스S 정품 무한 SL-T1670W     0.966348
# Epson Stylus Photo RX610 무한공급기    0.966218
# 삼성전자 SL-C565FW 스마트 알뜰토너           0.965667
# 삼성전자 MultiXpress SL-K3250NR       0.965140
# Name: ApeosPort 2560, dtype: float64

# %%
#사용자가 좋다고 평점매긴 것을 기준으로 상품추천.
def recommend_product(printer_sim_df, user_id, ori_ratings_df, num_recommendations=5):
    
    #item_user_table 평점 순서로 정렬
    sorted_ori_df = ori_ratings_df.sort_values(by=[user_id], ascending=False)
    product = sorted_ori_df.index[0]
    
    return product

# %%
product = recommend_product(printer_sim_df, '대표님', item_user_table, 10)

# %%
printer_sim_df[product].head()
# Out:
# 상품명              LG전자 LIP3310CW  LG전자 LIP3310CW  LG전자 LIP3310CW  \
# 상품명
# ApeosPort 2560         0.870847        0.788701        0.828177
# ApeosPort 3060         0.822269        0.701358        0.760907
# ApeosPort 3560         0.823279        0.853918        0.818175
# ApeosPort C2060        0.846985        0.804310        0.688477
# ApeosPort C2560        0.881425        0.785781        0.858166
#
# 상품명              LG전자 LIP3310CW  LG전자 LIP3310CW  LG전자 LIP3310CW  \
# 상품명
# ApeosPort 2560         0.856125        0.828294        0.826666
# ApeosPort 3060         0.666508        0.703319        0.769153
# ApeosPort 3560         0.805286        0.830304        0.731698
# ApeosPort C2060        0.840301        0.766060        0.711491
# ApeosPort C2560        0.799809        0.794751        0.782766
#
# 상품명              LG전자 LIP3310CW  LG전자 LIP3310CW  LG전자 LIP3310CW  \
# 상품명
# ApeosPort 2560         0.843287        0.828698        0.874406
# ...

# %%
recommend
# Out:
# 상품명
# ApeosPort 2560                    1.000000
# HP 오피스젯 프로 8720 무한공급기             0.986136
# Apeosport-II C2200 CP             0.971040
# Epson Stylus TX110 무한공급기          0.968365
# Epson Stylus Photo RX610          0.968288
# Canon IR C3125                    0.967145
# 삼성전자 잉크젯 플러스S 정품 무한 SL-T1670W     0.966348
# Epson Stylus Photo RX610 무한공급기    0.966218
# 삼성전자 SL-C565FW 스마트 알뜰토너           0.965667
# 삼성전자 MultiXpress SL-K3250NR       0.965140
# Name: ApeosPort 2560, dtype: float64
